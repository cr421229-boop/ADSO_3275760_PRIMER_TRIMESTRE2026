# %% [markdown]
# <a href="https://colab.research.google.com/github/Carolhernandez2616/ALGORITMIA_TERCER_TRIMESTRE/blob/main/CALCULADORA2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class operacion:
    def __init__(self,a,b):
        self.a = a
        self.b = b
        print("inicializando operacion")
    def calcular(self):
        print("\n==CALCULANDO OPERACION GENERICA==")
class suma(operacion):
    def __init__(self,a,b):
        super().__init__(a,b)
        print("preparando suma...")
    def calcular(self):
        super().calcular()
        resultado = int(self.a + self.b)
        print(f"El resultado de la suma es: {resultado} ")
class resta(operacion):
    def __init__(self,a,b):
        super().__init__(a,b)
        print("preparando resta...")
    def calcular(self):
        super().calcular()
        resultado = int(self.a - self.b)
        print(f"El resultado de la resta es: {resultado} ")
class multiplicacion(operacion):
    def __init__(self,a,b):
        super().__init__(a,b)
        print("preparando multiplicacion...")
    def calcular(self):
        super().calcular()
        resultado = int(self.a * self.b)
        print(f"El resultado de la multiplicacion es: {resultado} ")
class  division(operacion):
    def __init__(self,a,b):
        super().__init__(a,b)
        print("preparando division...")
    def calcular(self):
        if self.b == 0:
            print("Error: No se puede dividir por cero")
        else:
            super().calcular()
            resultado = int(self.a / self.b)
            print(f"El resultado de la  division es: {resultado} ")
class potencia(operacion):
    def __init__(self,a,b):
        super().__init__(a,b)
        print("preparando potencia..")
    def calcular(self):
        if self.b > 3:
            print("Error: No se puede potenciar a mas de tres")
        else:
            super().calcular()
            resultado = int(self.a ** self.b)
            print(f"El resultado de la potencia es: {resultado} ")
def main():
    num1 = float(input("\nIngrese el primer valor:  "))
    num2= float(input("Ingrese el segundo valor: "))
    print("\n==LA SUMA ES==")
    op1=suma(num1,num2)
    op1.calcular()
    num1 =float(input("\nIngrese el primer valor:  "))
    num2= float(input("Ingrese el segundo valor: "))
    print("\n==LA RESTA ES==")
    op1=resta(num1,num2)
    op1.calcular()
    num1 =float(input("\nIngrese el primer valor:  "))
    num2= float(input("Ingrese el segundo valor: "))
    print("\n==LA MULTIPLICACION ES==")
    op1=multiplicacion(num1,num2)
    num1 =float(input("\nIngrese el primer valor:  "))
    num2= float(input("Ingrese el segundo valor: "))
    print("\n==LA DIVISION ES==")
    op1=division(num1,num2)
    op1.calcular()
    num1 =float(input("\nIngrese el primer valor:  "))
    num2= float(input("Ingrese el segundo valor: "))
    print("\n==LA POTENCIA ES==")
    op1=potencia(num1,num2)
    op1.calcular()


if __name__=="__main__":
    main()
# Out:
# Ingrese el primer valor:  5
# Ingrese el segundo valor: 5
#
# ==LA SUMA ES==
# inicializando operacion
# preparando suma...
#
# ==CALCULANDO OPERACION GENERICA==
# El resultado de la suma es: 10
#
# Ingrese el primer valor:  7
# Ingrese el segundo valor: 7
#
# ==LA RESTA ES==
# inicializando operacion
# preparando resta...
#
# ==CALCULANDO OPERACION GENERICA==
# El resultado de la resta es: 0
#
# Ingrese el primer valor:  9
# Ingrese el segundo valor: 2
#
# ==LA MULTIPLICACION ES==
# inicializando operacion
# preparando multiplicacion...
#
# Ingrese el primer valor:  5
# Ingrese el segundo valor: 3
#
# ==LA DIVISION ES==
# inicializando operacion
# preparando division...
#
# ==CALCULANDO OPERACION GENERICA==
# El resultado de la  division es: 1
#
# Ingrese el primer valor:  2
# Ingrese el segundo valor: 2
#
# ==LA POTENCIA ES==
# inicializando operacion
# preparando potencia..
#
# ==CALCULANDO OPERACION GENERICA==
# El resultado de la potencia es: 4
