# %% [markdown]
# <a href="https://colab.research.google.com/github/Carolhernandez2616/ALGORITMIA_TERCER_TRIMESTRE/blob/main/COMPUTADOR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Computador:
    def __init__(self, CPU, PlacaBase, Memoria, DiscoDuro, GPU, Teclado, Mouse, Microfono, Camara, Wifi, Procesador, contraseña):
        self.CPU = CPU
        self.PlacaBase = PlacaBase
        self.Memoria = Memoria
        self.DiscoDuro = DiscoDuro
        self.GPU = GPU
        self.Teclado = Teclado
        self.Mouse = Mouse
        self.Microfono = Microfono
        self.Camara = Camara
        self.Wifi = Wifi
        self.Procesador = Procesador
        self.Contraseña = contraseña
    def mostrar__info(self):
        print("La CPU del computador es:  {self.CPU}")
        print("La placa base del computador es:  {self.PlacaBase}")
        print("La memoria del computador es:  {self.Memoria}")
        print("El disco duro del computador es:  {self.DiscoDuro} ")
        print("El GPU de computador es:  {self.GPU} ")
        print("El teclado del computador es:  {self.Teclado} ")
        print("El mouse del computador es:  {self.Mouse} ")
        print("El microfono del computador es:  {self.Microfono} ")
        print("La camara del computador es:  {self.Camara} ")
        print("El Wifi del computador es:  {self.Wifi} ")
        print("El procesador del computador es:  {self.Procesador} ")
        print("La contraseña del computador es:  {self.contraseña} ")
def main():
    CPU = input("Ingrese el nombre de la CPU:  ")
    PlacaBase = input("Ingrese el nombre de la Placa Base: ")
    Memoria = input("Ingrese el nombre de la memoria: ")
    DiscoDuro= input("Ingrese  el nombre del Disco Duro: ")
    GPU = input("Ingrese el nombre de la GPU: ")
    Teclado  = input("Ingrese el nombre del Teclado: ")
    Mouse  = input("Ingrese el nombre del Mouse: ")
    Microfono  = input("Ingrese el nombre del Microfono: ")
    Camara = input("Ingrese el nombre de la Camara: ")
    Wifi = input("Ingrese el nombre del  Wifi: ")
    Procesador  = input("Ingrese el nombre del  Procesador: ")
    contraseña = input("Ingrese su contraseña: ")
if __name__ == "__main__":
    main()
# Out:
# Ingrese el nombre de la CPU:  MD
# Ingrese el nombre de la Placa Base: ACS
# Ingrese el nombre de la memoria: 32G
# Ingrese  el nombre del Disco Duro: LOCAL
# Ingrese el nombre de la GPU: NKS
# Ingrese el nombre del Teclado: ASUS
# Ingrese el nombre del Mouse: RATON
# Ingrese el nombre del Microfono: RX
# Ingrese el nombre de la Camara: RINDEX
# Ingrese el nombre del  Wifi: CABLEMAZ
# Ingrese el nombre del  Procesador: YOLS
# Ingrese su contraseña: CASHTS
