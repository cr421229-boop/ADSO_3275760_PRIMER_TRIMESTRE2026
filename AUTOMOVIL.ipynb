# %% [markdown]
# <a href="https://colab.research.google.com/github/Carolhernandez2616/ALGORITMIA_TERCER_TRIMESTRE/blob/main/AUTOMOVIL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Automovil:
    def __init__(self, marca, modelo, color):
        self.marca = marca
        self.modelo = modelo
        self.color = color
    def mostrar__info(self):
        print(f"La marca del automovil es:  {self.marca}")
        print(f"El modelo del automovil es: {self.modelo}")
        print(f"El color del automovil es: {self.color}")
    def main():
        marca = input("Ingrese la marca del automovil  completo:  ")
        modelo = input("Ingrese el modelo del automovil:  ")
        color = input("Ingrese el color del automovil:  ")
    if __name__ == "__main__":
        main()
# Out:
# Ingrese la marca del automovil:  BMW
# Ingrese el modelo del automovil:  FORZA
# Ingrese el color del automovil:  ROJO
