# %% [markdown]
# <a href="https://colab.research.google.com/github/Carolhernandez2616/ALGORITMIA_TERCER_TRIMESTRE/blob/main/CLIENTE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Cliente:
    def __init__(self, Nombre,Apellido,numeroDocumento,Correo,Telefono):
        self.Nombre = Nombre
        self.Apellido = Apellido
        self.numeroDocumento = numeroDocumento
        self.Correo = Correo
        self.Telefono = Telefono
    def mostrar__info(self):
        print(f"Cual es su nombre es: {self.Nombre} ")
        print(f"Cual es su apellido: {self.Apellido} ")
        print(f"Cual es su numero documento: {self.numeroDocumento} ")
        print(f"Cual es su correo: {self.Correo}")
        print(f"Cual es su  telefono: {self.Telefono} ")
    def main():
        Nombre = input("Ingrese su  Nombre:  ")
        Apellido = input("Ingrese su Apellido:  ")
        numeroDocumento = input("Ingrese su Numero de Documento:  ")
        Correo = input("Ingrese su Correo:  ")
        Telefono = input("Ingrese su Telefono:  ")
    if __name__ == "__main__":
        main()
# Out:
# Ingrese su  Nombre:  Carol Yurley
# Ingrese su Apellido:  Hernandez Cuervo
# Ingrese su Numero de Documento:  1024497664
# Ingrese su Correo:  hernandezcuervocarolyurley@gmail.com
# Ingrese su Telefono:  3114407414
