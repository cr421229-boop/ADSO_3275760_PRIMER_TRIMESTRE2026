# %% [markdown]
# <a href="https://colab.research.google.com/github/Carolhernandez2616/ALGORITMIA_TERCER_TRIMESTRE/blob/main/CALCULADORA3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class operacion:
    def __init__(self,a,b):
        self.a = a
        self.b = b
    def validar(self):
        if not isinstance(self.a,(int,float)) or not isinstance (self.b,(int,float)):
         raise ValueError("Los valores deben ser numericos")
    def mostrar_datos(self):
        print(f"valores recibidos: {self.a} y {self.b}")

    def calcular(self):
        print("\n==REALIZANDO OPERACIONES MATEMATICAS==")
class suma(operacion):
        def calcular (self):
            super().validar()
            super().mostrar_datos()
            super().calcular()
            resultado= int(self.a + self.b)
            print(f"El resultado de la suma es: {resultado}")
class resta(operacion):
        def calcular (self):
            super().validar()
            super().mostrar_datos()
            super().calcular()
            resultado= int(self.a - self.b)
            print(f"El resultado de la resta es: {resultado}")
class multiplicacion(operacion):
        def calcular (self):
            super().validar()
            super().mostrar_datos()
            super().calcular()
            resultado= int(self.a * self.b)
            print(f"El resultado de la multiplicacion es: {resultado}")
class division(operacion):
        def calcular (self):
          if self.b == 0:
            print("Error: No se puede dividir por cero")
          else:
            super().validar()
            super().mostrar_datos()
            super().calcular()
            resultado= int(self.a / self.b)
            print(f"El resultado de la division es: {resultado}")
class potencia(operacion):
        def calcular (self):
            if self.b > 3:
                print("Error: No se puede potenciar a mas de tres")
            else:
                super().validar()
                super().mostrar_datos()
                super().calcular()
            resultado= int(self.a ** self.b)
            print(f"El resultado de la potencia es: {resultado}")
def main():
    num1=float(input("\nIngrese el primer numero:  "))
    num2=float(input("Ingrese el segundo numero:  "))
    print("\n======OPERACION SUMA======")
    operacionsuma= suma(num1,num2)
    operacionsuma.calcular()
    num1=float(input("\nIngrese el primer numero:  "))
    num2=float(input("Ingrese el segundo numero:  "))
    print("\n======OPERACION RESTA======")
    operacionresta= resta(num1,num2)
    operacionresta.calcular()
    num1=float(input("\nIngrese el primer numero:  "))
    num2=float(input("Ingrese el segundo numero:  "))
    print("\n======OPERACION MULTIPLICACION======")
    operacionmultiplicacion= multiplicacion(num1,num2)
    operacionmultiplicacion.calcular()
    num1=float(input("\nIngrese el primer numero:  "))
    num2=float(input("Ingrese el segundo numero:  "))
    print("\n======OPERACION DIVISION======")
    operaciondivision= division(num1,num2)
    operaciondivision.calcular()
    num1=float(input("\nIngrese el primer numero:  "))
    num2=float(input("Ingrese el segundo numero:  "))
    print("\n======OPERACION POTENCIA======")
    operacionpotencia= potencia(num1,num2)
    operacionpotencia.calcular()

if __name__=="__main__":
    main()
# Out:
# Ingrese el primer numero:  2
# Ingrese el segundo numero:  2
#
# ======OPERACION SUMA======
# valores recibidos: 2.0 y 2.0
#
# ==REALIZANDO OPERACIONES MATEMATICAS==
# El resultado de la suma es: 4
#
# Ingrese el primer numero:  3
# Ingrese el segundo numero:  2
#
# ======OPERACION RESTA======
# valores recibidos: 3.0 y 2.0
#
# ==REALIZANDO OPERACIONES MATEMATICAS==
# El resultado de la resta es: 1
#
# Ingrese el primer numero:  3
# Ingrese el segundo numero:  7
#
# ======OPERACION MULTIPLICACION======
# valores recibidos: 3.0 y 7.0
#
# ==REALIZANDO OPERACIONES MATEMATICAS==
# El resultado de la multiplicacion es: 21
#
# Ingrese el primer numero:  5
# Ingrese el segundo numero:  6
#
# ======OPERACION DIVISION======
# valores recibidos: 5.0 y 6.0
#
# ==REALIZANDO OPERACIONES MATEMATICAS==
# El resultado de la division es: 0
#
# Ingrese el primer numero:  2
# Ingrese el segundo numero:  2
#
# ======OPERACION POTENCIA======
# valores recibidos: 2.0 y 2.0
#
# ...
